# %% [markdown]
# <a href="https://colab.research.google.com/github/arashsajjadi/Hyper-parameter-optimization/blob/main/Raytune_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ray in /usr/local/lib/python3.7/dist-packages (1.13.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.7/dist-packages (from ray) (20.15.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray) (3.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray) (3.7.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray) (1.43.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray) (1.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray) (21.4.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (4.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (5.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2022.6.15)
# Requirement already satisfied: distlib<1,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray) (0.3.4)
# Requirement already satisfied: platformdirs<3,>=2 in /usr/local/lib/python3.7/dist-packages (from virtualenv->ray) (2.5.2)

# %%
pip install featurewiz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: featurewiz in /usr/local/lib/python3.7/dist-packages (0.1.82)
# Requirement already satisfied: dask>=2021.11.0 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (2022.2.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from featurewiz) (5.5.0)
# Requirement already satisfied: distributed>=2021.11.0 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (2022.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from featurewiz) (3.2.2)
# Requirement already satisfied: xgboost>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (1.6.1)
# Requirement already satisfied: fsspec>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (2022.5.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from featurewiz) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (1.0.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from featurewiz) (2.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from featurewiz) (4.64.0)
# Requirement already satisfied: lightgbm>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (3.3.2)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (1.3.5)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from featurewiz) (0.11.2)
# Requirement already satisfied: pyarrow==7.0.0 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (7.0.0)
# Requirement already satisfied: imbalanced-learn>=0.7 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (0.8.1)
# Requirement already satisfied: category-encoders in /usr/local/lib/python3.7/dist-packages (from featurewiz) (2.5.0)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.7/dist-packages (from featurewiz) (1.0.0)
# Requirement already satisfied: Pillow~=9.0.0 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (9.0.1)
# Requirement already satisfied: feather-format>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from featurewiz) (0.4.1)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow==7.0.0->featurewiz) (1.21.6)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.11.0->featurewiz) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.11.0->featurewiz) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.11.0->featurewiz) (21.3)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.11.0->featurewiz) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.11.0->featurewiz) (6.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (5.4.8)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (2.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (2.11.3)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (5.1.1)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (7.1.2)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (57.4.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.11.0->featurewiz) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn>=0.7->featurewiz) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn>=0.7->featurewiz) (1.4.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.2.1->featurewiz) (0.37.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->dask>=2021.11.0->featurewiz) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3.4->featurewiz) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3.4->featurewiz) (2.8.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask>=2021.11.0->featurewiz) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.3.4->featurewiz) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.2->featurewiz) (3.1.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2021.11.0->featurewiz) (1.0.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders->featurewiz) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category-encoders->featurewiz) (0.10.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->featurewiz) (1.0.18)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->featurewiz) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2021.11.0->featurewiz) (2.0.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (7.7.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (5.6.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (4.10.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (5.2.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (5.3.1)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.7/dist-packages (from jupyter->featurewiz) (5.3.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter->featurewiz) (5.3.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->featurewiz) (1.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->featurewiz) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->featurewiz) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->jupyter->featurewiz) (5.4.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (2.15.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (0.18.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (4.11.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->featurewiz) (3.8.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->featurewiz) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter->featurewiz) (0.13.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel->jupyter->featurewiz) (23.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->jupyter->featurewiz) (0.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->featurewiz) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->featurewiz) (0.11.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (5.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (0.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter->featurewiz) (0.8.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupyter->featurewiz) (0.5.1)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from qtconsole->jupyter->featurewiz) (2.1.0)

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader,  TensorDataset, Dataset
import torch.nn.functional as F
from ray import tune
import os
import ray
from ray.tune.schedulers import ASHAScheduler
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.model_selection import train_test_split
#from torchmetrics import ConfusionMatrix
#confmat = ConfusionMatrix(num_classes=2)
from sklearn.metrics import balanced_accuracy_score
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
from sklearn.metrics import roc_auc_score

# %%
#read data
initial_targets=pd.read_csv("bbbp.csv")
initial_features=pd.read_csv("bbbp_global_cdf_rdkit.csv")

initial_features=initial_features.loc[:, (initial_features != initial_features.iloc[0]).any()] 

shuffled_targets=initial_targets.sample(frac=1,random_state=1234).reset_index(drop=True)
shuffled_features=initial_features.sample(frac=1,random_state=1234).reset_index(drop=True)
#shuffling the data to randomize the sequence

X_train, X_test, y_train, y_test = train_test_split(shuffled_features,shuffled_targets["p_np"],test_size=0.1, random_state=1234, stratify=shuffled_targets["p_np"])
X_train, X_valid, y_train, y_valid = train_test_split(X_train,y_train,test_size=0.22, random_state=1234, stratify=y_train)

# %%
Data=pd.concat([X_train, y_train], axis=1) #reshape data for featurewiz feature selection
target = ['p_np']
from featurewiz import featurewiz 
feature_selection = featurewiz(Data, target, corr_limit=0.9, verbose=2,header=0, nrows=None,outputs="features")
# Out:
# ############################################################################################
# ############       F A S T   F E A T U R E  E N G G    A N D    S E L E C T I O N ! ########
# # Be judicious with featurewiz. Don't use it to create too many un-interpretable features! #
# ############################################################################################
# You supplied outputs = features
# Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
# **INFO: featurewiz can now read feather formatted files. Loading train data...
#     Shape of your Data Set loaded: (1431, 186)
#     Loaded train data. Shape = (1431, 186)
#     Some column names had special characters which were removed...
# No test data filename given...
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     185 Predictors classified...
#         No variables were removed since no ID or low-information variables found in data set
# GPU active on this device
#     Tuning XGBoost using GPU hyper-parameters. This will take time...
#     After removing redundant variables from further processing, features left = 185
# No interactions created for categorical vars since feature engg does not specify it
# #### Single_Label Binary_Classification problem ####
# #######################################################################################
# #####  Searching for Uncorrelated List Of Variables (SULOV) in 185 features ############
# #######################################################################################
#     there are no null values in dataset...
#     Removing (36) highly correlated variables:
# Time taken for SULOV method = 2 seconds
#     Adding 0 categorical variables to reduced numeric variables  of 149
# Final list of selected vars after SULOV = 149
# Readying dataset for Recursive XGBoost by converting all features to numeric...
# #######################################################################################
# #####    R E C U R S I V E   X G B O O S T : F E A T U R E   S E L E C T I O N  #######
# #######################################################################################
#     using regular XGBoost
# Train and Test loaded into Dask dataframes successfully after feature_engg completed
# Current number of predictors = 149
#     XGBoost version: 1.6.1
# Number of booster rounds = 100
#         using 149 variables...
#             Time taken for regular XGBoost feature selection = 2 seconds
#         using 119 variables...
#             Time taken for regular XGBoost feature selection = 4 seconds
#         using 89 variables...
#             Time taken for regular XGBoost feature selection = 5 seconds
#         using 59 variables...
#             Time taken for regular XGBoost feature selection = 7 seconds
#         using 29 variables...
#             Time taken for regular XGBoost feature selection = 9 seconds
#             Total time taken for XGBoost feature selection = 11 seconds
# #######################################################################################
# #####          F E A T U R E   S E L E C T I O N   C O M P L E T E D            #######
# #######################################################################################
# Selected 66 important features. Too many to print...
#
#     Time taken for feature selection = 13 seconds
# Returning 2 dataframes: dataname and test_data with 66 important features.

# %%
X_train=X_train[feature_selection[0]]
X_valid=X_valid[feature_selection[0]]
X_test=X_test[feature_selection[0]]
y_train=pd.DataFrame(data=y_train)
y_valid=pd.DataFrame(data=y_valid)
y_test=pd.DataFrame(data=y_test)

# %%
class BbbpDataset_train (Dataset):
    def __init__(self,transform=None):
        #data loading
        self.x=X_train.to_numpy().astype("float32")
        self.y=y_train.to_numpy().astype("float32")
        self.n_samples=X_train.shape[0]
        self.transform=transform
    def __getitem__(self, index):
        sample=self.x[index], self.y[index]
        if self.transform:
            sample=self.transform(sample)
        return sample
    def __len__(self):
        return self.n_samples

class BbbpDataset_valid (Dataset):
    def __init__(self,transform=None):
        #data loading
        self.x=X_valid.to_numpy().astype("float32")
        self.y=y_valid.to_numpy().astype("float32")
        self.n_samples=X_valid.shape[0]
        self.transform=transform
    def __getitem__(self, index):
        sample=self.x[index], self.y[index]
        if self.transform:
            sample=self.transform(sample)
        return sample
    def __len__(self):
        return self.n_samples

class BbbpDataset_test (Dataset):
    def __init__(self,transform=None):
        #data loading
        self.x=X_test.to_numpy().astype("float32")
        self.y=y_test.to_numpy().astype("float32")
        self.n_samples=X_test.shape[0]
        self.transform=transform
    def __getitem__(self, index):
        sample=self.x[index], self.y[index]
        if self.transform:
            sample=self.transform(sample)
        return sample
    def __len__(self):
        return self.n_samples
    
class ToTensor():
    def __call__(self,sample):
        inputs,targets=sample
        inputs=torch.from_numpy(inputs.astype("float32"))
        targets=torch.tensor(targets.astype("float32"))
        #targets=targets.view(targets.shape[0],1)
        return inputs,targets

#training set ---------------------------------------------------
training_set = BbbpDataset_train(transform=ToTensor())    
train_loader = DataLoader(dataset=training_set,
                          batch_size=64,
                          shuffle=True)

dataiter_train = iter(train_loader)
data_train = dataiter_train.next()


def trainloader(config):
    return  DataLoader(dataset=training_set,
                          batch_size=config["batch_size"],
                          shuffle=True,num_workers=2)
#validation set ---------------------------------------------------
validation_set = BbbpDataset_valid(transform=ToTensor())    
valid_loader = DataLoader(dataset=validation_set,
                          batch_size=64,
                          shuffle=True)

dataiter_valid = iter(valid_loader)
data_valid = dataiter_valid.next()

def validloader(config):
    return  DataLoader(dataset=validation_set,
                          batch_size=config["batch_size"],
                          shuffle=True,num_workers=2)
#test set ---------------------------------------------------
test_set = BbbpDataset_test(transform=ToTensor())    
test_loader = DataLoader(dataset=test_set,
                          batch_size=8,
                          shuffle=False)

dataiter_test = iter(test_loader)
data_test = dataiter_test.next()

def testloader(config):
    return  DataLoader(dataset=test_set,
                          batch_size=config["batch_size"],
                          shuffle=False,num_workers=2)

# %%
n_samples,n_features=X_train.shape
class NeuralNetwork (nn.Module):
    def __init__(self,n_input_features,l1, l2,l3):
        super (NeuralNetwork, self).__init__()
        self.linear1=nn.Linear(n_input_features,4*math.floor(n_input_features/2)+l1)
        self.linear2=nn.Linear(l1+4*math.floor(n_input_features/2),math.floor(n_input_features/2)+l2)
        self.linear3=nn.Linear(math.floor(n_input_features/2)+l2,math.floor(n_input_features/3)+l3)
        self.linear4=nn.Linear(math.floor(n_input_features/3)+l3,math.floor(n_input_features/6))
        self.linear5=nn.Linear(math.floor(n_input_features/6),1)
    def forward(self,x):
        out=torch.relu (self.linear1(x))
        out=torch.relu(self.linear2(out))
        out=torch.relu(self.linear3(out))
        out=torch.tanh(self.linear4(out))
        out=torch.sigmoid(self.linear5(out))
        y_predicted=out
        return y_predicted

# %%
def train_Bbbp(config,checkpoint_dir=None):
    net = NeuralNetwork(np.shape(feature_selection[0])[0],config["l1"],config["l2"],config["l3"])
    
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)
    
    #
    criterion=nn.BCELoss()
    optimizer=torch.optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)
    
    
    # The `checkpoint_dir` parameter gets passed by Ray Tune when a checkpoint
    # should be restored.
    if checkpoint_dir:
        checkpoint = os.path.join(checkpoint_dir, "checkpoint")
        model_state, optimizer_state = torch.load(checkpoint)
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    
    for epoch in range(10):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader(config), 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,running_loss / epoch_steps))
                running_loss = 0.0
    
        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(validloader(config), 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1
        #with torch.no_grad():
        #  print(f'the correct is {correct:.2f}, total is {total:.2f}, loss = {loss:.2f} , roc_auc_score={roc_auc_score(labels_val,out_val):6f}')
        # Here we save a checkpoint. It is automatically registered with
        # Ray Tune and will potentially be passed as the `checkpoint_dir`
        # parameter in future iterations.
        with tune.checkpoint_dir(step=epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save(
                (net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %%
def test_best_model(best_trial):
    best_trained_model = NeuralNetwork(np.shape(feature_selection[0])[0],best_trial.config["l1"],best_trial.config["l2"],best_trial.config["l3"])
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    best_trained_model.to(device)

    checkpoint_path = os.path.join(best_trial.checkpoint.value, "checkpoint")

    model_state, optimizer_state = torch.load(checkpoint_path)
    best_trained_model.load_state_dict(model_state)

    #trainset, testset = load_data()

    #testloader = torch.utils.data.DataLoader(
    #    testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            features, labels = data
            features, labels = features.to(device), labels.to(device)
            outputs = best_trained_model(features)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()


    print("Best trial test set accuracy: {}".format(correct / total))

# %%
config = {
    "l1": tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
    "l2": tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
    "l3": tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
    "lr": tune.loguniform(1e-4, 1e-1),
    "batch_size": tune.choice([2, 4, 8, 16, 32, 64, 128]),
}

# %%
def main(num_samples=10, max_num_epochs=100, gpus_per_trial=2):
    config = {
        "l1": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "l2": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "l3": tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
        "lr": tune.loguniform(1e-4, 1e-1),
        "batch_size": tune.choice([2, 4, 8, 16])
    }
    scheduler = ASHAScheduler(
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    result = tune.run(
        tune.with_parameters(train_Bbbp),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        metric="loss",
        mode="min",
        num_samples=num_samples,
        scheduler=scheduler
    )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    if ray.util.client.ray.is_connected():
        # If using Ray Client, we want to make sure checkpoint access
        # happens on the server. So we wrap `test_best_model` in a Ray task.
        # We have to make sure it gets executed on the same node that
        # ``tune.run`` is called on.
        from ray.util.ml_utils.node import force_on_current_node
        remote_fn = force_on_current_node(ray.remote(test_best_model))
        ray.get(remote_fn.remote(best_trial))
    else:
        print("--------------------------------------------------")
        test_best_model(best_trial)

main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
# Out:
# 2022-06-27 08:03:46,153	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==<br>Current time: 2022-06-27 08:03:53 (running for 00:00:07.07)<br>Memory usage on this node: 2.7/12.7 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>RUNNING </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00000:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-03-56
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.33749911388253223
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 3.348109483718872
#   time_this_iter_s: 3.348109483718872
#   time_total_s: 3.348109483718872
#   timestamp: 1656317036
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00000
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:03:56 (running for 00:00:10.42)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -0.33749911388253223<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.33749911388253223 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>RUNNING </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.34811</td><td style="text-align: right;">0.337499</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00000:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-02
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 3
#   loss: 0.31815330193627
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 9.136710166931152
#   time_this_iter_s: 2.1858527660369873
#   time_total_s: 9.136710166931152
#   timestamp: 1656317042
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: ab4c3_00000
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:02 (running for 00:00:16.21)<br>Memory usage on this node: 2.7/12.7 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -0.3259315012705208 | Iter 1.000: -0.33749911388253223<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.31815330193627 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>RUNNING </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">     3</td><td style="text-align: right;">         9.13671</td><td style="text-align: right;">0.318153</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00000:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-08
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 5
#   loss: 0.3575975622539178
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 15.332214832305908
#   time_this_iter_s: 3.6269376277923584
#   time_total_s: 15.332214832305908
#   timestamp: 1656317048
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: ab4c3_00000
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:08 (running for 00:00:22.41)<br>Memory usage on this node: 2.7/12.7 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3259315012705208 | Iter 1.000: -0.33749911388253223<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3575975622539178 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>RUNNING </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">     5</td><td style="text-align: right;">         15.3322</td><td style="text-align: right;">0.357598</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00000:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-15
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 8
#   loss: 0.3181102082760322
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 22.523160457611084
#   time_this_iter_s: 2.320462942123413
#   time_total_s: 22.523160457611084
#   timestamp: 1656317055
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: ab4c3_00000
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:15 (running for 00:00:29.60)<br>Memory usage on this node: 2.7/12.7 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3259315012705208 | Iter 1.000: -0.33749911388253223<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3181102082760322 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (9 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>RUNNING </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">     8</td><td style="text-align: right;">         22.5232</td><td style="text-align: right;">0.31811</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">       </td><td style="text-align: right;">          </td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00000:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-20
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 10
#   loss: 0.3336549640291988
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 26.975827932357788
#   time_this_iter_s: 2.257687568664551
#   time_total_s: 26.975827932357788
#   timestamp: 1656317060
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: ab4c3_00000
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00001:
#   accuracy: 0.47029702970297027
#   date: 2022-06-27_08-04-24
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.5254597981082331
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 3.825551986694336
#   time_this_iter_s: 3.825551986694336
#   time_total_s: 3.825551986694336
#   timestamp: 1656317064
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00001
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:24 (running for 00:00:37.91)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3259315012705208 | Iter 1.000: -0.4314794559953826<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3336549640291988 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (8 PENDING, 1 RUNNING, 1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>RUNNING   </td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82555</td><td style="text-align: right;">0.52546 </td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">    10</td><td style="text-align: right;">        26.9758 </td><td style="text-align: right;">0.333655</td><td style="text-align: right;">  0.940594</td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00002:
#   accuracy: 1.8712871287128714
#   date: 2022-06-27_08-04-24
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.6180247232025745
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 0.8259904384613037
#   time_this_iter_s: 0.8259904384613037
#   time_total_s: 0.8259904384613037
#   timestamp: 1656317064
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00002
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00003:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-26
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.5409202038651646
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 1.5842070579528809
#   time_this_iter_s: 1.5842070579528809
#   time_total_s: 1.5842070579528809
#   timestamp: 1656317066
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00003
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00004:
#   accuracy: 0.47029702970297027
#   date: 2022-06-27_08-04-29
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.4241567614239336
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 2.8292782306671143
#   time_this_iter_s: 2.8292782306671143
#   time_total_s: 2.8292782306671143
#   timestamp: 1656317069
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00004
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:29 (running for 00:00:43.21)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3259315012705208 | Iter 1.000: -0.5254597981082331<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3336549640291988 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (5 PENDING, 1 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>RUNNING   </td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">     1</td><td style="text-align: right;">         2.82928</td><td style="text-align: right;">0.424157</td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">    10</td><td style="text-align: right;">        26.9758 </td><td style="text-align: right;">0.333655</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">     1</td><td style="text-align: right;">         3.82555</td><td style="text-align: right;">0.52546 </td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">     1</td><td style="text-align: right;">         0.82599</td><td style="text-align: right;">0.618025</td><td style="text-align: right;">  1.87129 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.58421</td><td style="text-align: right;">0.54092 </td><td style="text-align: right;">  0.940594</td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00004:
#   accuracy: 0.47029702970297027
#   date: 2022-06-27_08-04-32
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 2
#   loss: 0.354096224946477
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 5.690093517303467
#   time_this_iter_s: 2.8608152866363525
#   time_total_s: 5.690093517303467
#   timestamp: 1656317072
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: ab4c3_00004
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00005:
#   accuracy: 0.47029702970297027
#   date: 2022-06-27_08-04-35
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.6308606626963852
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 2.8812026977539062
#   time_this_iter_s: 2.8812026977539062
#   time_total_s: 2.8812026977539062
#   timestamp: 1656317075
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00005
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:35 (running for 00:00:48.99)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=6
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3400138631084989 | Iter 1.000: -0.5331900009866988<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3336549640291988 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (4 PENDING, 1 RUNNING, 5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>RUNNING   </td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">     1</td><td style="text-align: right;">         2.8812 </td><td style="text-align: right;">0.630861</td><td style="text-align: right;">  0.470297</td></tr>
# ...
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00006:
#   accuracy: 1.8712871287128714
#   date: 2022-06-27_08-04-36
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.5690424097519294
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 0.9192664623260498
#   time_this_iter_s: 0.9192664623260498
#   time_total_s: 0.9192664623260498
#   timestamp: 1656317076
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00006
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00007:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-37
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.3555791335973409
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 1.6838788986206055
#   time_this_iter_s: 1.6838788986206055
#   time_total_s: 1.6838788986206055
#   timestamp: 1656317077
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00007
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00007:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-39
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 2
#   loss: 0.44979388716787394
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 3.2666263580322266
#   time_this_iter_s: 1.582747459411621
#   time_total_s: 3.2666263580322266
#   timestamp: 1656317079
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: ab4c3_00007
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00008:
#   accuracy: 0.9405940594059405
#   date: 2022-06-27_08-04-40
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.5527821026816226
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 1.5450670719146729
#   time_this_iter_s: 1.5450670719146729
#   time_total_s: 1.5450670719146729
#   timestamp: 1656317080
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00008
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:40 (running for 00:00:54.78)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.354096224946477 | Iter 1.000: -0.5409202038651646<br>Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3336549640291988 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (1 PENDING, 1 RUNNING, 8 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>RUNNING   </td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.54507 </td><td style="text-align: right;">0.552782</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>PENDING   </td><td>               </td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">        </td><td style="text-align: right;">          </td></tr>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">    10</td><td style="text-align: right;">       26.9758  </td><td style="text-align: right;">0.333655</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">     1</td><td style="text-align: right;">        3.82555 </td><td style="text-align: right;">0.52546 </td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.82599 </td><td style="text-align: right;">0.618025</td><td style="text-align: right;">  1.87129 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.58421 </td><td style="text-align: right;">0.54092 </td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">     2</td><td style="text-align: right;">        5.69009 </td><td style="text-align: right;">0.354096</td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">     1</td><td style="text-align: right;">        2.8812  </td><td style="text-align: right;">0.630861</td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.919266</td><td style="text-align: right;">0.569042</td><td style="text-align: right;">  1.87129 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">     2</td><td style="text-align: right;">        3.26663 </td><td style="text-align: right;">0.449794</td><td style="text-align: right;">  0.940594</td></tr>
# </tbody>
# </table><br><br>
# Result for train_Bbbp_ab4c3_00009:
#   accuracy: 1.8712871287128714
#   date: 2022-06-27_08-04-41
#   done: false
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 1
#   loss: 0.39130278165433924
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 0.979151725769043
#   time_this_iter_s: 0.979151725769043
#   time_total_s: 0.979151725769043
#   timestamp: 1656317081
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ab4c3_00009
#   warmup_time: 0.012903451919555664
#
# Result for train_Bbbp_ab4c3_00009:
#   accuracy: 1.8712871287128714
#   date: 2022-06-27_08-04-42
#   done: true
#   experiment_id: 72f9a72b5de7458f9f5bb406d93a4c03
#   hostname: 2c92e425b060
#   iterations_since_restore: 2
#   loss: 0.36922037966695487
#   node_ip: 172.28.0.2
#   pid: 6449
#   should_checkpoint: true
#   time_since_restore: 1.87556791305542
#   time_this_iter_s: 0.896416187286377
#   time_total_s: 1.87556791305542
#   timestamp: 1656317082
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: ab4c3_00009
#   warmup_time: 0.012903451919555664
# == Status ==<br>Current time: 2022-06-27 08:04:42 (running for 00:00:56.70)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 8.000: -0.3181102082760322 | Iter 4.000: -0.3411614216937877 | Iter 2.000: -0.3616583023067159 | Iter 1.000: -0.5331900009866988<br>Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects<br>Current best trial: ab4c3_00000 with loss=0.3336549640291988 and parameters={'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}<br>Result logdir: /root/ray_results/train_Bbbp_2022-06-27_08-03-46<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  l3</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_Bbbp_ab4c3_00000</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0401158  </td><td style="text-align: right;">    10</td><td style="text-align: right;">       26.9758  </td><td style="text-align: right;">0.333655</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00001</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.0010645  </td><td style="text-align: right;">     1</td><td style="text-align: right;">        3.82555 </td><td style="text-align: right;">0.52546 </td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00002</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;">  32</td><td style="text-align: right;">  32</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000235214</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.82599 </td><td style="text-align: right;">0.618025</td><td style="text-align: right;">  1.87129 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00003</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;"> 128</td><td style="text-align: right;">0.00209218 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.58421 </td><td style="text-align: right;">0.54092 </td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00004</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  32</td><td style="text-align: right;">  16</td><td style="text-align: right;">   8</td><td style="text-align: right;">0.0494601  </td><td style="text-align: right;">     2</td><td style="text-align: right;">        5.69009 </td><td style="text-align: right;">0.354096</td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00005</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           2</td><td style="text-align: right;">  16</td><td style="text-align: right;">  64</td><td style="text-align: right;">  64</td><td style="text-align: right;">0.000118363</td><td style="text-align: right;">     1</td><td style="text-align: right;">        2.8812  </td><td style="text-align: right;">0.630861</td><td style="text-align: right;">  0.470297</td></tr>
# <tr><td>train_Bbbp_ab4c3_00006</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.00107474 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.919266</td><td style="text-align: right;">0.569042</td><td style="text-align: right;">  1.87129 </td></tr>
# <tr><td>train_Bbbp_ab4c3_00007</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0299067  </td><td style="text-align: right;">     2</td><td style="text-align: right;">        3.26663 </td><td style="text-align: right;">0.449794</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00008</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           4</td><td style="text-align: right;"> 256</td><td style="text-align: right;">  64</td><td style="text-align: right;">  16</td><td style="text-align: right;">0.000947217</td><td style="text-align: right;">     1</td><td style="text-align: right;">        1.54507 </td><td style="text-align: right;">0.552782</td><td style="text-align: right;">  0.940594</td></tr>
# <tr><td>train_Bbbp_ab4c3_00009</td><td>TERMINATED</td><td>172.28.0.2:6449</td><td style="text-align: right;">           8</td><td style="text-align: right;">  64</td><td style="text-align: right;"> 256</td><td style="text-align: right;"> 256</td><td style="text-align: right;">0.0394598  </td><td style="text-align: right;">     2</td><td style="text-align: right;">        1.87557 </td><td style="text-align: right;">0.36922 </td><td style="text-align: right;">  1.87129 </td></tr>
# </tbody>
# </table><br><br>
# 2022-06-27 08:04:43,099	INFO tune.py:748 -- Total run time: 57.02 seconds (56.69 seconds for the tuning loop).
# Best trial config: {'l1': 32, 'l2': 32, 'l3': 8, 'lr': 0.040115780637943084, 'batch_size': 4}
# Best trial final validation loss: 0.3336549640291988
# Best trial final validation accuracy: 0.9405940594059405
# --------------------------------------------------
# Best trial test set accuracy: 1.8823529411764706
